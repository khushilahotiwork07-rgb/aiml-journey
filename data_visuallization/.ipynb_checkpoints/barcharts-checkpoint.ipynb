# %%
import matplotlib.pyplot as plt

# %%
year = (2010 , 2011 , 2012 , 2013 )
population = (100 , 103 , 107 , 97)
plt.bar (year , population , color ="red")
plt.xlabel("years")
plt.ylabel("population in crores")
plt.title("population increade in years")
# Out:
# Text(0.5, 1.0, 'population increade in years')

# %%
import matplotlib.pyplot as plt
year = (2010 , 2011 , 2012 , 2013 )
population = (100 , 103 , 107 , 97)
plt.bar (year , population , color ="red")
plt.xlabel("years")
plt.ylabel("population in crores")
plt.title("population increade in years")
for i in range(len(year)):
        plt.text(year [i] ,population [i]+1 ,str(population[i] , ha="center"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 9
#       5 plt.xlabel("years")
#       6 plt.ylabel("population in crores")
#       7 plt.title("population increade in years")
#       8 for i in range(len(year)):
# ----> 9         plt.text(year [i] ,population [i]+1 ,str(population[i] , ha="center"))
#
# TypeError: 'ha' is an invalid keyword argument for str()

# %%
non_oscar_revenue = [105, 210, 208, 150, 64]
oscar_revenue = [98, 156, 230, 112, 125]
years = [2000, 2001, 2002, 2003, 2004]

x = np.arange(len(years))
width = 0.4

plt.bar(x - width/2, oscar_revenue, width, label="Oscar Movies")
plt.bar(x + width/2, non_oscar_revenue, width, label="Non-Oscar Movies")

#plt.xticks(x, years)
plt.xlabel("Years")
plt.ylabel("Revenue (Million $)")
plt.title("Oscar vs Non-Oscar Movie Revenue")
plt.legend()

plt.show()

# %%
country =["india" , "nepal" ,"pakistan" , "bangladesh"]
population = [150 , 20 , 102 , 67]
plt.barh(country , population )
# Out:
# <BarContainer object of 4 artists>
