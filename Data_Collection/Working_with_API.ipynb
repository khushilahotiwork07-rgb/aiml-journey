# %%
import requests

# %%
URL = "https://catfact.ninja/factp"
res = requests.get(URL)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 URL = "https://catfact.ninja/fact"
# ----> 2 res = requests.get(URL)
#
# NameError: name 'requests' is not defined

# %%
res
# Out:
# <Response [200]>

# %%
data = res.json()
data
# Out:
# {'fact': 'The heaviest cat on record is Himmy, a Tabby from Queensland, Australia. He weighed nearly 47 pounds (21 kg). He died at the age of 10.',
#  'length': 135}

# %%
res = requests.get("
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 json_data = res.json()
#       2 print(json_data)
#
# NameError: name 'res' is not defined

# %%
df = pd.json_normalize(json_data["fact"]) 
print(json_data)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df = pd.json_normalize(json_data["fact"])
#       2 print(json_data)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\json\_normalize.py:445, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     443     data = list(data)
#     444 else:
# --> 445     raise NotImplementedError
#     447 # check to see if a simple recursive function is possible to
#     448 # improve performance (see #15621) but only for cases such
#     449 # as pd.Dataframe(data) or pd.Dataframe(data, sep)
#     450 if (
#     451     record_path is None
#     452     and meta is None
#    (...)    455     and max_level is None
#     456 ):
#
# NotImplementedError:
